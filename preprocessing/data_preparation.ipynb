# %% [markdown]
# # Import librerie

# %%
import requests
import sys

import numpy as np

from pyspark.sql.functions import when, count, isnan, isnull, expr, col, current_date, date_format, year, month, lag, sum, round, max, min, udf, datediff, explode, lit, upper, lower, regexp_replace, to_date, monotonically_increasing_id, split, concat, arrays_zip, array

from pyspark.sql.types import IntegerType, StringType, FloatType, BooleanType

# %% [markdown]
# # Lettura dei dati

# %%
files = [
  'DATASET_COMPLETO',
  'DATASET_PICCOLO',
  'CLASSE_A',
  'CLASSE_H'
]


dict_path =  {
  'DATASET' : "/FileStore/tables/DATASET_COMPLETO.csv",
  'CLASSE_A' : "/FileStore/tables/Classe_A.csv",
  'CLASSE_H' : "/FileStore/tables/Classe_H.csv"
}

# %% [markdown]
# ## Dataset rielaborato

# %%
file_type = "csv"
infer_schema = "true"
first_row_is_header = "true"
delimiter = ","

df = spark.read.format(file_type) \
  .option("inferSchema", infer_schema) \
  .option("header", first_row_is_header) \
  .option("sep", delimiter) \
  .option("multiLine", "true") \
  .option("engine", "python") \
  .option("encoding", "ISO-8859-1") \
  .load(dict_path['DATASET'])


display(df)

# %%
print("Numero di entry DATASET_COMPLETO:", df.count())

# %% [markdown]
# ## Dati Farmaci Classe A

# %%
file_type = "csv"
infer_schema = "true"
first_row_is_header = "true"
delimiter = ";"

farmaci_gtA = spark.read.format(file_type) \
  .option("inferSchema", infer_schema) \
  .option("header", first_row_is_header) \
  .option("sep", delimiter) \
  .option("multiLine", "true") \
  .option("engine", "python") \
  .option("encoding", "ISO-8859-1") \
  .load(dict_path['CLASSE_A'])

display(farmaci_gtA)

# %% [markdown]
# ## Dati Farmaci Classe H

# %%
file_type = "csv"
infer_schema = "true"
first_row_is_header = "true"
delimiter = ";"

farmaci_gtH = spark.read.format(file_type) \
  .option("inferSchema", infer_schema) \
  .option("header", first_row_is_header) \
  .option("sep", delimiter) \
  .option("multiLine", "true") \
  .option("engine", "python") \
  .option("encoding", "ISO-8859-1") \
  .load(dict_path['CLASSE_H'])

display(farmaci_gtH)

# %% [markdown]
# ## Aggiunta ID vistita

# %%
df = df.withColumn("ID_VISITA", monotonically_increasing_id())

# %% [markdown]
# # Preparazione Dati visita

# %%
df_visita = df.select('ID_VISITA', 'CODPAZ', 'SESSO', 'ETA', 'PESO', 'ALTEZZA', 'DATA_EVENTO', 'ESAMINATORE', 'COD_MEDICO_FIRMANTE')
display(df_visita)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>ID_VISITA</th><th>CODPAZ</th><th>SESSO</th><th>ETA</th><th>PESO</th><th>ALTEZZA</th><th>DATA_EVENTO</th><th>ESAMINATORE</th><th>COD_MEDICO_FIRMANTE</th></tr></thead><tbody><tr><td>0</td><td>7</td><td>null</td><td>null</td><td>80.0</td><td>163.0</td><td>2008-03-27</td><td>null</td><td>null</td></tr><tr><td>1</td><td>7</td><td>null</td><td>null</td><td>80.0</td><td>163.0</td><td>2008-06-10</td><td>null</td><td>null</td></tr><tr><td>2</td><td>1</td><td>null</td><td>null</td><td>null</td><td>null</td><td>2019-03-29</td><td>null</td><td>null</td></tr><tr><td>3</td><td>1</td><td>null</td><td>null</td><td>null</td><td>null</td><td>2019-05-03</td><td>null</td><td>null</td></tr><tr><td>4</td><td>1</td><td>null</td><td>null</td><td>null</td><td>165.0</td><td>2019-11-25</td><td>null</td><td>null</td></tr><tr><td>5</td><td>1</td><td>null</td><td>null</td><td>null</td><td>165.0</td><td>2020-07-15</td><td>null</td><td>1_61</td></tr><tr><td>6</td><td>1</td><td>null</td><td>null</td><td>null</td><td>165.0</td><td>2020-10-12</td><td>null</td><td>null</td></tr><tr><td>7</td><td>7</td><td>null</td><td>null</td><td>76.0</td><td>163.0</td><

# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>ID_VISITA</th><th>CODPAZ</th><th>SESSO</th><th>ETA</th><th>PESO</th><th>ALTEZZA</th><th>DATA_EVENTO</th><th>ESAMINATORE</th><th>COD_MEDICO_FIRMANTE</th></tr></thead><tbody><tr><td>0</td><td>0</td><td>113345</td><td>113494</td><td>29402</td><td>11591</td><td>0</td><td>89975</td><td>66837</td></tr></tbody></table></div>

# %%
# %fs rm -r "dbfs:/FileStore/preprocessing/DF_VISITA_COMPLETO"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">res2: Boolean = true
# </div>

# %%
df_visita.coalesce(1).write.format("com.databricks.spark.csv").option("header", "true").save("dbfs:/FileStore/preprocessing/DF_VISITA_COMPLETO")

# %% [markdown]
# # Preparazione Anamnesi e Diagnosi

# %%
df_anam_dia = df.select("ID_VISITA", "ANAMNESI", "DIAGNOSI")
display(df_anam_dia)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>ID_VISITA</th><th>ANAMNESI</th><th>DIAGNOSI</th></tr></thead><tbody><tr><td>0</td><td>null</td><td>Ipertensione Arteriosa Grado I STADIO II. Ipercolesterolemia. Intolleranza glicidica
# Controllo farmacologico efficace. Pregressa Fibrillazione atriale.Gastropatia polipoide.</td></tr><tr><td>1</td><td>null</td><td>Ipertensione Arteriosa Grado I STADIO II. Ipercolesterolemia. Intolleranza glicidica
# Controllo farmacologico efficace. Pregressa Fibrillazione atriale.Gastropatia polipoide.</td></tr><tr><td>2</td><td>null</td><td>Prossimo controllo prenotabile tra circa 12 mesi: Tel 0817462247 (da martedÃ¬ a giovedÃ¬ 08.30-13.00); mail: Cardiologia riabilitativa.FEDII@gmail.com
# CODICI PRESTAZIONI: VISITA DI CONTROLLO PER IPERTENSIONE (89010.064)
# ELETTROCARDIOGRAMMA (89520.001)
# Torni al prossimo controllo con impegnativa del medico curante per Ã§Visita di controllo cardiologica per scompenso (cod. 89010.125), Elettrocardiogramma (cod. 89520.001), EcocolorDoppler cardiaco a riposo ( cod. 88723.001)Ã§.</td></tr><tr><td>3</td><td>null</td><td>CODICI IMPEGNATIVA PROSSIMO CONTROLLO:
# VISITA DI CONTROLLO PER IPERTENSIONE (89010.064)
#
# ELETTROCARDIOGRAMMA (89520.001)</td></tr><tr><td>4</td><td>null</td><td>VISITA DI CONTROLLO CARDIOLOGICA (89010.014) ELETTROCARDIOGRAMMA (89520.001)
# Prossimo controllo prenotabile tra circa 12 mesi: Tel 0817462247 (da martedÃ¬ a giovedÃ¬ 10.00-12.30); mail: centroipertensionefedericoII@gmail.com</td></tr><tr><td>5</td><td>null</td><td>Prossimo controllo prenotabile tra circa 12 mesi: Tel 0817462247 (da martedÃ¬ a giovedÃ¬ 08.30-13.00); mail: centroipertensione.federicoII@gmail.com
# CODICI PRESTAZIONI: VISITA DI CONTROLLO PER IPERTENSIONE (89010.064)
# ELETTROCARDIOGRAMMA (89520.001)</td></tr><tr><td>6</td><td>null</td><td>CODICI PRESTAZIONI: VISITA DI CONTROLLO PER IPERTENSIONE (89010.064)
# ELETTROCARDIOGRAMMA (89520.001)
# Prossimo controllo prenotabile tra circa 12 mesi: inviare l`impegnativa alla mail: centroipertensionefedericoII@gmail.com</td></tr><tr><td>7</td><td>null</td><td>null</td></tr><tr><td>8</td><td>null</td><td>null</td></tr><tr><td>9</td><td>null</td><td>Ipertensione Arteriosa Grado I STADIO II Ipercolesterolemia. Intolleranza glicidica
# Controllo farmacologico efficace
# www.centroipertensione.it</td></tr><tr><td>10</td><td>null</td><td>Ipertensione Arteriosa Grado I STADIO II Ipercolesterolemia. Intolleranza glicidica
# Controllo farmacologico efficace. Pregressa Fibrillazione atriale
# www.centroipertensione.it</td></tr><tr><td>11</td><td>null</td><td>Gastropatia polipoide (in attesa di referto bioptico). Ipertensione arteriosa.</td></tr><tr><td>12</td><td>null</td><td>Ipertensione Arteriosa Grado I STADIO II Ipercolesterolemia. Intolleranza glicidica
# Controllo farmacologico efficace. Pregressa Fibrillazione atriale.Gastropatia polipoide.
# www.centroipertensione.it</td></tr><tr><td>13</td><td>null</td><td>Ipertensione Arteriosa Grado I STADIO II Ipercolesterolemia. Intolleranza glicidica
# Controllo farmacologico efficace. Pregressa Fibrillazione atriale.Gastropatia polipoide.
# www.centroipertensione.it</td></tr><tr><td>14</td><td>null</td><td>Ipertensione Arteriosa Grado I STADIO II. Ipercolesterolemia. Intolleranza glicidica
# Controllo farmacologico efficace. Pregressa Fibrillazione atriale.Gastropatia polipoide.
# www.centroipertensione.it</td></tr><tr><td>15</td><td>null</td><td>Ipertensione Arteriosa Grado I STADIO II. Ipercolesterolemia. Intolleranza glicidica
# Controllo farmacologico efficace. Pregressa Fibrillazione atriale.Gastropatia polipoide.</td></tr><tr><td>16</td><td>null</td><td>Ipertensione Arteriosa Grado I STADIO II. Ipercolesterolemia. Intolleranza glicidica
# Controllo farmacologico efficace. Pregressa Fibrillazione atriale.Gastropatia polipoide.</td></tr><tr><td>17</td><td>null</td><td>Ipertensione Arteriosa Grado I STADIO II. Ipercolesterolemia. Intolleranza glicidica
# Controllo farmacologico efficace. Pregressa Fibrillazione atriale.Gastropatia polipoide.</td></tr><tr><td>18</td><td>null</td><td>Ipertensione Arteriosa Grado I STADIO II. Ipercolesterolemia. Intolleranza glicidica
# Controllo farmacologico efficace. Pregressa Fibrillazione atriale.Gastropatia polipoide.</td></tr><tr><td>19</td><td>null</td><td>Ipertensione Arteriosa Grado I STADIO II. Ipercolesterolemia. Intolleranza glicidica
# Controllo farmacologico efficace. Pregressa Fibrillazione atriale.Gastropatia polipoide.</td></tr><tr><td>20</td><td>null</td><td>Ipertensione Arteriosa Grado I STADIO II. Ipercolesterolemia. Intolleranza glicidica
# Controllo farmacologico efficace. Pregressa Fibrillazione atriale.Gastropatia polipoide.</td></tr><tr><td>21</td><td>null</td><td>Ipertensione Arteriosa Grado I STADIO II. Ipercolesterolemia. Intolleranza glicidica
# Controllo farmacologico efficace. Pregressa Fibrillazione atriale.Gastropatia polipoide.</td></tr><tr><td>22</td><td>null</td><td>Ipertensione Arteriosa Grado I STADIO II. Ipercolesterolemia. Intolleranza glicidica
# Controllo farmacologico efficace. Pregressa Fibrillazione atriale.Gastropatia polipoide.</td></tr><tr><td>23</td><td>null</td><td>Ipertensione Arteriosa Grado I STADIO II. Ipercolesterolemia. Intolleranza glicidica
# Controllo farmacologico efficace. Pregressa Fibrillazione atriale.Gastropatia polipoide.
# Malattia di Parkinson</td></tr><tr><td>24</td><td>null</td><td>null</td></tr><tr><td>25</td><td>null</td><td>Ipertensione Arteriosa Grado I STADIO II. Ipercolesterolemia. Intolleranza glicidica
# Controllo farmacologico efficace. Pregressa Fibrillazione atriale.Gastropatia polipoide.</td></tr><tr><td>26</td><td>null</td><td>Ipertensione Arteriosa Grado I STADIO II. Ipercolesterolemia. Intolleranza glicidica
# Controllo farmacologico efficace. Pregressa Fibrillazione atriale.Gastropatia polipoide.
# Malattia di Parkinson</td></tr><tr><td>27</td><td>null</td><td>Ipertensione Arteriosa Grado I STADIO II. Ipercolesterolemia. Intolleranza glicidica
# Controllo farmacologico efficace. Pregressa Fibrillazione atriale.Gastropatia polipoide.
# Malattia di Parkinson</td></tr><tr><td>28</td><td>null</td><td>null</td></tr><tr><td>29</td><td>null</td><td>Ipertensione Arteriosa Grado I STADIO II. Ipercolesterolemia. Intolleranza glicidica. Malattia di Parkinson
# Controllo farmacologico efficace.
# Pregressa Fibrillazione atriale.Gastropatia polipoide.
# E` consigliabile effettuare gli esami indicati annualmente
# Controllo pressorio domiciliare SMS ( 2v/Settimana)
# La Cartella Clinica Ã¨ consultabile su: www.campaniasalute.com
# Il MMG per emergenze puo` telefonare al 3334420888 (call Center)</td></tr><tr><td>30</td><td>null</td><td>Ipertensione Arteriosa Grado I STADIO II. Ipercolesterolemia. Intolleranza glicidica. Malattia di Parkinson
# Controllo farmacologico efficace.
# Pregressa Fibrillazione atriale.Gastropatia polipoide.
# E` consigliabile effettuare gli esami indicati annualmente
# Controllo pressorio domiciliare SMS ( 2v/Settimana)
# La Cartella Clinica Ã¨ consultabile su: www.campaniasalute.com
# Il MMG per emergenze puo` telefonare al 3334420888 (call Center)</td></tr><tr><td>31</td><td>null</td><td>Ipertensione Arteriosa Grado I STADIO II. Ipercolesterolemia. Intolleranza glicidica. Malattia di Parkinson
# Controllo farmacologico efficace.
# Pregressa Fibrillazione atriale.Gastropatia polipoide.
# E` consigliabile effettuare gli esami indicati annualmente
# Controllo pressorio domiciliare  ( 2v/Settimana)
# La Cartella Clinica Ã¨ consultabile su: www.campaniasalute.com
# Il MMG per emergenze puo` telefonare al 3334420888 (call Center)</td></tr><tr><td>32</td><td>null</td><td>Ipertensione Arteriosa Grado I STADIO II. Ipercolesterolemia. Intolleranza glicidica. Malattia di Parkinson
# Contro

# %%
#%fs rm -r dbfs:/FileStore/preprocessing/DF_ANAM_DIA_COMPLETO
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_anam_dia.coalesce(1).write.format("com.databricks.spark.csv").option("header", "true").save("dbfs:/FileStore/preprocessing/DF_ANAM_DIA_COMPLETO")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# # Preparazione farmaci

# %% [markdown]
# ### Cleaning dei nomi

# %%
for i in range(1,11):
  colonna = 'FARMACO' + str(i)
  colonna_new = 'FARMACO' + str(i) + '_CLEAN'
  df = df.withColumn(colonna_new, upper(col(colonna))).withColumn(colonna_new, regexp_replace(colonna_new, ' MG|\d+MG| MCG|\d+MCG| MGR|\d+MGR|\d+GR| GR| CPR| COMPRESSE| CEROTTO| CEROTTI| GOCCE| GEL| GTT| BUST| FL| UI| SPRAY|\d+CPR| CP|\d+CP|[^a-zA-Z0-9_ ]|\d+', ''))
  df = df.withColumn(colonna_new, regexp_replace(colonna_new, '^[ \t]+|[ \t]+$', ''))
  df = df.withColumn(colonna_new, regexp_replace(colonna_new, '[ \t]+', ' '))

# %%
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>CODPAZ</th><th>SESSO</th><th>ETA</th><th>PESO</th><th>ALTEZZA</th><th>DATA_EVENTO</th><th>COD_MEDICO_FIRMANTE</th><th>DIAGNOSI</th><th>FARMACO1</th><th>FARMACO2</th><th>FARMACO3</th><th>FARMACO4</th><th>FARMACO5</th><th>FARMACO6</th><th>FARMACO7</th><th>FARMACO8</th><th>FARMACO9</th><th>FARMACO10</th><th>DOSE_FARMACO1</th><th>DOSE_FARMACO2</th><th>DOSE_FARMACO3</th><th>DOSE_FARMACO4</th><th>DOSE_FARMACO5</th><th>DOSE_FARMACO6</th><th>DOSE_FARMACO7</th><th>DOSE_FARMACO8</th><th>DOSE_FARMACO9</th><th>DOSE_FARMACO10</th><th>ANAMNESI</th><th>ESAMINATORE</th><th>ID_VISITA</th><th>FARMACO1_CLEAN</th><th>FARMACO2_CLEAN</th><th>FARMACO3_CLEAN</th><th>FARMACO4_CLEAN</th><th>FARMACO5_CLEAN</th><th>FARMACO6_CLEAN</th><th>FARMACO7_CLEAN</th><th>FARMACO8_CLEAN</th><th>FARMACO9_CLEAN</th><th>FARMACO10_CLEAN</th></tr></thead><tbody><tr><td>7</td><td>null</td><td>null</td><td>80.0</td><td>163.0</td><td>2008-03-27</td><td>null</td><td>Ipertensione Arteriosa Grado I STADIO II. Ipercolesterolemia. Intolleranza glicidica
# Controllo farmacologico efficace. Pregressa Fibrillazione atriale.Gastropatia polipoide.</td><td>RATACAND 16 mg</td><td>LOPRESOR</td><td>ARMOLIPID</td><td>MAALOX 400mg</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>1/2 al mattino</td><td>1/2 al mattino e alla sera</td><td>un/una alla sera</td><td>ogni 8 ore</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>0</td><td>RATACAND</td><td>LOPRESOR</td><td>ARMOLIPID</td><td>MAALOX</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>7</td><td>null</td><td>null</td><td>80.0</td><td>163.0</td><td>2008-06-10</td><td>null</td><td>Ipertensione Arteriosa Grado I STADIO II. Ipercolesterolemia. Intolleranza glicidica
# Controllo farmacologico efficace. Pregressa Fibrillazione atriale.Gastropatia polipoide.</td><td>RATACAND 16 mg</td><td>LOPRESOR</td><td>LIMPIDEX 15 mg</td><td>MAALOX PLUS</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>1/2 al mattino</td><td>1/2 al mattino e alla sera</td><td>ore 07.00 ore 22.00</td><td>ore 10.00 e ore 17.00</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>1</td><td>RATACAND</td><td>LOPRESOR</td><td>LIMPIDEX</td><td>MAALOX PLUS</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>1</td><td>null</td><td>null</td><td>null</td><td>null</td><td>2019-03-29</td><td>null</td><td>Prossimo controllo prenotabile tra circa 12 mesi: Tel 0817462247 (da martedÃ¬ a giovedÃ¬ 08.30-13.00); mail: Cardiologia riabilitativa.FEDII@gmail.com
# CODICI PRESTAZIONI: VISITA DI CONTROLLO PER IPERTENSIONE (89010.064)
# ELETTROCARDIOGRAMMA (89520.001)
# Torni al prossimo controllo con impegnativa del medico curante per Ã§Visita di controllo cardiologica per scompenso (cod. 89010.125), Elettrocardiogramma (cod. 89520.001), EcocolorDoppler cardiaco a riposo ( cod. 88723.001)Ã§.</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>2</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>1</td><td>null</td><td>null</td><td>null</td><td>null</td><td>2019-05-03</td><td>null</td><td>CODICI IMPEGNATIVA PROSSIMO CONTROLLO:
# VISITA DI CONTROLLO PER IPERTENSIONE (89010.064)
#
# ELETTROCARDIOGRAMMA (89520.001)</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>3</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>1</td><td>null</td><td>null</td><td>null</td><td>165.0</td><td>2019-11-25</td><td>null</td><td>VISITA DI CONTROLLO CARDIOLOGICA (89010.014) ELETTROCARDIOGRAMMA (89520.001)
# Prossimo controllo prenotabile tra circa 12 mesi: Tel 0817462247 (da martedÃ¬ a giovedÃ¬ 10.00-12.30); mail: centroipertensionefedericoII@gmail.com</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>4</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>1</td><td>null</td><td>null</td><td>null</td><td>165.0</td><td>2020-07-15</td><td>1_61</td><td>Prossimo controllo prenotabile tra circa 12 mesi: Tel 0817462247 (da martedÃ¬ a giovedÃ¬ 08.30-13.00); mail: centroipertensione.federicoII@gmail.com
# CODICI PRESTAZIONI: VISITA DI CONTROLLO PER IPERTENSIONE (89010.064)
# ELETTROCARDIOGRAMMA (89520.001)</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>5</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>1</td><td>null</td><td>null</td><td>null</td><td>165.0</td><td>2020-10-12</td><td>null</td><td>CODICI PRESTAZIONI: VISITA DI CONTROLLO PER IPERTENSIONE (89010.064)
# ELETTROCARDIOGRAMMA (89520.001)
# Prossimo controllo prenotabile tra circa 12 mesi: inviare l`impegnativa alla mail: centroipertensionefedericoII@gmail.com</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>6</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>7</td><td>null</td><td>null</td><td>76.0</td><td>163.0</td><td>1998-11-11</td><td>null</td><td>null</td><td>lopresor</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>un/una al mattino</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>7</td><td>LOPRESOR</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>7</td><td>null</td><td>null</td><td>76.0</td><td>163.0</td><td>2003-12-04</td><td>null</td><td>null</td><td>LOPRESOR</td><td>SIVASTIN</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>8</td><td>LOPRESOR</td><td>SIVASTIN</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>7</td><td>null</td><td>null</td><td>75.0</td><td>163.0</td><td>2

# %% [markdown]
# ### Creazione dataframe con tutti i farmaci

# %%
union = df.withColumn("farmaci", array('FARMACO1_CLEAN', 'FARMACO2_CLEAN', 'FARMACO3_CLEAN', 'FARMACO4_CLEAN', 'FARMACO5_CLEAN', 'FARMACO6_CLEAN', 'FARMACO7_CLEAN', 'FARMACO8_CLEAN', 'FARMACO9_CLEAN', 'FARMACO10_CLEAN')).select("farmaci").withColumn("farmaci", explode("farmaci"))

union = union.where(~union.farmaci.isNull()).where(union.farmaci != "").distinct()
display(union)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>farmaci</th></tr></thead><tbody><tr><td>PRAVASTATINA</td></tr><tr><td>RATACAND PLUS</td></tr><tr><td>IRRODAN</td></tr><tr><td>PERDIPINA</td></tr><tr><td>FARALZIN</td></tr><tr><td>ZOPRAZIDE</td></tr><tr><td>NIFEDICOR R</td></tr><tr><td>MEXAFORM</td></tr><tr><td>NITRODERM</td></tr><tr><td>OMINIC</td></tr><tr><td>SIRIO</td></tr><tr><td>HUMULIN R</td></tr><tr><td>NICAPRESS R</td></tr><tr><td>PRILACE</td></tr><tr><td>PASADEN</td></tr><tr><td>PANTECTA</td></tr><tr><td>TERAPIA INSUL A PARTE</td></tr><tr><td>REQUIP</td></tr><tr><td>TORADIUR</td></tr><tr><td>RIGENTEX</td></tr><tr><td>CONVERTEN</td></tr><tr><td>CARVIPRES</td></tr><tr><td>AVANDAMET</td></tr><tr><td>PLEIAMIDE</td></tr><tr><td>ENAPREN</td></tr><tr><td>IMOVANE</td></tr><tr><td>INTEGRATORI DI MAGNESIO</td></tr><tr><td>COUMADIN</td></tr><tr><td>BLOPRES</td></tr><tr><td>CONPETACT</td></tr><tr><td>DIETA IPOGLICIDICA</td></tr><tr><td>GLICONORM</td></tr><tr><td>UNOPROST</td></tr><tr><td>ISOSORBIDE MONITRATO</td></tr><tr><td>DIBASE</td></tr><tr><td>NITRODERMTTS</td></tr><tr><td>GLOBUREN U I</td></tr><tr><td>LAEVOLAC SCIROPPO</td></tr><tr><td>NOVONORM LANTU
r><tr><td>TICLOPIDINA DOC</td></tr><tr><td>CONDIUREN</td></tr><tr><td>FERROGRAD</td></tr><tr><td>LEXOTAN X</td></tr><tr><td>SEVIKAR</td></tr><tr><td>GAVISCON ADVANCEINE</td></tr><tr><td>FISITENS</td></tr><tr><td>PRINIVL</td></tr><tr><td>DECADURABOLIN</td></tr><tr><td>TRITTICO</td></tr><tr><td>ANSIOLIN</td></tr><tr><td>SMETTERE DI FUMARE</td></tr><tr><td>GLIBOMET</td></tr><tr><td>NITRODUR</td></tr><tr><td>LEXOTAN</td></tr><tr><td>PLENDIL</td></tr><tr><td>NIFE ...

# %%
print("Numero di farmaci distinti nel dataset:", union.count())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Numero di farmaci distinti nel dataset: 4888
# </div>

# %% [markdown]
# ### Distanza di Levenshtein

# %%
@udf(returnType= StringType()) 
def levenshtein(s, t):
    # Inizializza una matrica di zeri
    rows = len(s)+1
    cols = len(t)+1
    distance = np.zeros((rows,cols),dtype = int)

    # Popola la matrice iniziale con gli indici di ogni carattere di entrambe le stringhe
    for i in range(1, rows):
        for k in range(1,cols):
            distance[i][0] = i
            distance[0][k] = k

    # Itera sulla matrice per calcolare il costo delle cancellazioni, inserimenti e/o sostituzioni 
    for col in range(1, cols):
        for row in range(1, rows):
            if s[row-1] == t[col-1]:
                # Se i caratteri sono gli stessi nelle due stringhe in una data posizione [i,j] allora il costo è 0
                cost = 0 
            else:
                cost = 2
            distance[row][col] = np.min([distance[row-1][col] + 1,  # Costo della cancellazione
                                 distance[row][col-1] + 1,          # Costo dell'inserimento
                                 distance[row-1][col-1] + cost])    # Costo della sostituzione

    # Calcolo del Levenshtein Distance Ratio
    Ratio = ((len(s)+len(t)) - distance[row][col]) / (len(s)+len(t))
    return str(Ratio)

# %% [markdown]
# #### Creazione ground truth

# %%
split_col = split(farmaci_gtA['Denominazione e Confezione'], '\\*')
farmaci_gtA = farmaci_gtA.withColumn('Farmaco', split_col.getItem(0)).select('Farmaco').distinct()
split_col = split(farmaci_gtH['Denominazione e Confezione'], '\\*')
farmaci_gtH = farmaci_gtH.withColumn('Farmaco', split_col.getItem(0)).select('Farmaco').distinct()
farmaci_gt = farmaci_gtA.select('Farmaco').union(farmaci_gtH.select('Farmaco')).distinct().withColumnRenamed('Farmaco', 'farmaci_corretti')
print("Numero di farmaci ground truth:", farmaci_gt.count())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Numero di farmaci ground truth: 3210
# </div>

# %%
gt = union.join(farmaci_gt.withColumnRenamed('farmaci_corretti', 'farmaci'), on='farmaci', how='inner')
display(gt)
print("Numero di farmaci ground truth:", gt.count())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>farmaci</th></tr></thead><tbody><tr><td>PRAVASTATINA</td></tr><tr><td>RATACAND PLUS</td></tr><tr><td>FARALZIN</td></tr><tr><td>SULIDAMOR</td></tr><tr><td>KROVANEG</td></tr><tr><td>ZOPRAZIDE</td></tr><tr><td>INTRON A</td></tr><tr><td>ADROVANCE</td></tr><tr><td>AMINOMAL</td></tr><tr><td>SOPAVI</td></tr><tr><td>SIRIO</td></tr><tr><td>HUMULIN R</td></tr><tr><td>PRILACE</td></tr><tr><td>PANTECTA</td></t
><td>TRINIPLAS</td></tr><tr><td>PERITRATE</td></tr><tr><td>ANNISTER</td></tr><tr><td>ELONTRIL</td></tr><tr><td>CALCIO</td></tr><tr><td>DEURSIL</td></tr><tr><td>TENSOGARD</td></tr><tr><td>PULMAXAN</td></tr><tr><td>MAORIS</td></tr><tr><td>EUTIROX</td></tr><tr><td>FEMARA</td></tr><tr><td>GLICLAZIDE</td></tr><tr><td>MESTINON</td></tr><tr><td>VOKANAMET</td></tr><tr><td>PLAUNAC</td></tr><tr><td>ZYLLT</td></tr><tr><td>PRITOR</td></tr><tr><td>CONDIUREN</td></tr><tr><td>SEVIKAR</td></tr><tr><td>EFEXOR</td></tr><tr><td>URSOBIL</td></tr><tr><td>SEVELAMER</td></tr><tr><td>RIFADIN</td></tr><tr><td>TRITTICO</td></tr><tr><td>XYZAL</td></tr><tr><td>ANAFRANIL</td></tr><tr><td>OCTREOTIDE</td></tr><tr><td>GLIBOMET</td></tr><tr><td>ZYVOXID</td></tr><tr><td>PLENDIL</td></tr><tr><td>NIFEDICOR</td></tr><tr><td>TEGRETOL</td></tr><tr><td>SUCRALFIN</td></tr><tr><td>LEDERFOLIN</td></tr><tr><td>ARIPIPRAZOLO</td></tr><tr><td>ACTRAPID</td></tr><tr><td>TRIPLIAM</td></tr><tr><td>LOPRESOR</td></tr><tr><td>ZYLORIC</td></tr><tr><td>PANTOPRAZOLO</td></tr><tr><td>ELITEN</td></tr><tr><td>INITISS</td></tr><tr><td>LOSARTAN</td></tr><tr><td>XALATAN</td></tr><tr><td>PEGINTRON</td></tr><tr><td>CIALIS</td></tr><tr><td ...
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Numero di farmaci ground truth: 1011
# </div>

# %%
anti = union.join(gt, on="farmaci", how='anti')
print("Numero di farmaci del dataset non presenti nella GT:", anti.count())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Numero di farmaci del dataset non presenti nella GT: 3877
# </div>

# %% [markdown]
# #### Calcolo tabella di similarità

# %%
cross = anti.select("farmaci").withColumnRenamed('farmaci', 'farmaci_misspelled').crossJoin(gt.withColumnRenamed("farmaci", "farmaci_corretti").select('farmaci_corretti'))
similarity = cross.withColumn("result", levenshtein(cross.farmaci_misspelled, cross.farmaci_corretti))
similarity = similarity.withColumn("result", similarity["result"].cast("float"))
similarity_09 = similarity.filter(similarity.result >= 0.9)

# %%
# %fs rm -r "/FileStore/preprocessing/similarity_09-gt-efficiente-dataset-completo"

# %%
similarity_09.coalesce(1).write.format("com.databricks.spark.csv").option("header", "true").save("/FileStore/preprocessing/similarity_09-gt-efficiente-dataset-completo")

# %% [markdown]
# ### Correzione nomi farmaci

# %%
file_location = "/FileStore/tables/similarity_09_gt_efficiente_dataset_completo.csv"
file_type = "csv"
infer_schema = "true"
first_row_is_header = "true"
delimiter = ","

similarity_09 = spark.read.format(file_type) \
  .option("inferSchema", infer_schema) \
  .option("header", first_row_is_header) \
  .option("sep", delimiter) \
  .load(file_location)

display(similarity_09)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>farmaci_misspelled</th><th>farmaci_corretti</th><th>result</th></tr></thead><tbody><tr><td>PRAVSTATINA</td><td>PRAVASTATINA</td><td>0.95652175</td></tr><tr><td>RATACANDPLUS</td><td>RATACAND PLUS</td><td>0.96</td></tr><tr><td>RATCAND PLUS</td><td>RATACAND PLUS</td><td>0.96</td></tr><tr><td>RATACND PLUS</td><td>RATACAND PLUS</td><td>0.96</td></tr><tr><td>INTRONA</td><td
SOTALOLO</td><td>0.9411765</td></tr><tr><td>ACIFDO FOLICO</td><td>ACIDO FOLICO</td><td>0.96</td></tr><tr><td>IVRABRADINA</td><td>IVABRADINA</td><td>0.95238096</td></tr><tr><td>METAFORAL</td><td>METFORAL</td><td>0.9411765</td></tr><tr><td>METOFORAL</td><td>METFORAL</td><td>0.9411765</td></tr><tr><td>EUTUIROX</td><td>EUTIROX</td><td>0.93333334</td></tr><tr><td>EUTROX</td><td>EUTIROX</td><td>0.9230769</td></tr><tr><td>EUTIROXS</td><td>EUTIROX</td><td>0.93333334</td></tr><tr><td>EURTIROX</td><td>EUTIROX</td><td>0.93333334</td></tr><tr><td>EUIROX</td><td>EUTIROX</td><td>0.9230769</td></tr><tr><td>GLICAZIDE</td><td>GLICLAZIDE</td><td>0.94736844</td></tr><tr><td>PLAUNCAC</td><td>PLAUNAC</td><td>0.93333334</td></tr><tr><td>PLUNAC</td><td>PLAUNAC</td><td>0.9230769</td></tr><tr><td>PRITO</td><td>PRITOR</td><td>0.90909094</td></tr><tr><td>CODIUREN</td><td>CONDIUREN</td><td>0.9411765</td></tr><tr><td>SEVIKA</td><td>SEVIKAR</td><td>0.9230769</td></tr><tr><td>EFFEXOR</td><td>EFEXOR</td><td>0.9230769</td></tr><tr><td>GLIBOMETT</td><td>GLIBOMET</td><td>0.9 ...

# %%
print("Numero di corrispondenze con confidenza >0.9:", similarity_09.count())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Numero di corrispondenze con confidenza &gt;0.9: 581
# </div>

# %% [markdown]
# #### Creazione tabella delle corrispondenze

# %%
temp = similarity_09.groupBy("farmaci_misspelled").max("result")
mapping = temp.join(similarity_09.withColumnRenamed("result", "max(result)"), on=["max(result)", "farmaci_misspelled"]).orderBy("farmaci_misspelled")
display(mapping)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>max(result)</th><th>farmaci_misspelled</th><th>farmaci_corretti</th></tr></thead><tbody><tr><td>0.962963</td><td>AATORVASTATINA</td><td>ATORVASTATINA</td></tr><tr><td>0.9411765</td><td>ABSORCORL</td><td>ABSORCOL</td></tr><tr><td>0.9411765</td><td>ACCURETC</td><td>ACCURETIC</td></tr><tr><td>0.93333334</td><td>ACEQUID</td><td>ACEQUIDE</td></tr><tr><td>0.9411765</td><td>ACESITEM</td><td>ACESISTEM</td></tr><tr><td>0.96</td><td>ACIFDO FOLICO</td><td>ACIDO FOLICO</td></tr><tr><td>0.9411765</td><td>ACRIPTIN</td><td>ASCRIPTIN</td></tr><tr><td>0.93333334</td><td>ACUPRIN</td><td>ACCUPRIN</td></tr><tr><td>0.9411765</td><td>ACURETIC</td><td>ACCURETIC</td></tr><tr><td>0.90909094</td><td>ADALA CRON</td><td>ADALAT CRONO</td></tr><tr><td>0.95652175</td><td>ADALA CRONO</td><td>ADALAT CRONO</td></tr><tr><td>0.90909094</td><td>ADALACRONO</td><td>ADALAT CRONO</td></tr><tr><td>0.96</td><td>ADALACT CRONO</td><td>ADALAT CRONO</td></tr><tr><td>0.9166667</td><td>ADALAL CRONO</td><td>ADALAT CRONO</td></tr><tr><td>0.9166667</td><td>ADALAR CRONO</td><td>ADALAT CRONO</td></
ASPIRIN</td></tr><tr><td>0.9230769</td><td>AROVEL</td><td>APROVEL</td></tr><tr><td>0.94736844</td><td>ASCRIPITIN</td><td>ASCRIPTIN</td></tr><tr><td>0.94736844</td><td>ASCRITPTIN</td><td>ASCRIPTIN</td></tr><tr><td>0.9411765</td><td>ASCRPTIN</td><td>ASCRIPTIN</td></tr><tr><td>0.9411765</td><td>ASRIPTIN</td><td>ASCRIPTIN</td></tr><tr><td>0.9230769</td><td>ATENOLO</td><td>ATENOL</td></tr><tr><td>0.941176 ...

# %%
print("Numero di mapping decretati:", mapping.count())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Numero di mapping decretati: 580
# </div>

# %% [markdown]
# #### Sostituzione misspelling

# %%
df_farmaci = df.drop("SESSO", "ETA", "PESO", "ALTEZZA", "ANAMNESI", "DIAGNOSI", "CODPAZ", "COD_MEDICO_FIRMANTE", "DATA_EVENTO")

df_zip = df_farmaci.withColumn("FARMACO", array('FARMACO1_CLEAN', 'FARMACO2_CLEAN', 'FARMACO3_CLEAN', 'FARMACO4_CLEAN', 'FARMACO5_CLEAN', 'FARMACO6_CLEAN', 'FARMACO7_CLEAN', 'FARMACO8_CLEAN', 'FARMACO9_CLEAN', 'FARMACO10_CLEAN')).withColumn("CONFEZIONE", array('FARMACO1', 'FARMACO2', 'FARMACO3', 'FARMACO4', 'FARMACO5', 'FARMACO6', 'FARMACO7', 'FARMACO8', 'FARMACO9', 'FARMACO10')).withColumn("DOSE", array('DOSE_FARMACO1', 'DOSE_FARMACO2', 'DOSE_FARMACO3', 'DOSE_FARMACO4', 'DOSE_FARMACO5', 'DOSE_FARMACO6', 'DOSE_FARMACO7', 'DOSE_FARMACO8', 'DOSE_FARMACO9', 'DOSE_FARMACO10')).select("ID_VISITA", "FARMACO", "CONFEZIONE", "DOSE")

df_farmaci = df_zip.withColumn("tmp", arrays_zip("FARMACO", "CONFEZIONE", "DOSE")) \
  .withColumn("tmp", explode("tmp")) \
  .select("ID_VISITA", "tmp.FARMACO", "tmp.CONFEZIONE", "tmp.DOSE") \
  .dropna(subset="FARMACO")

# %%
display(df_farmaci)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>ID_VISITA</th><th>FARMACO</th><th>CONFEZIONE</th><th>DOSE</th></tr></thead><tbody><tr><td>0</td><td>RATACAND</td><td>RATACAND 16 mg</td><td>1/2 al mattino</td></tr><tr><td>0</td><td>LOPRESOR</td><td>LOPRESOR</td><td>1/2 al mattino e alla sera</td></tr><tr><td>0</td><td>ARMOLIPID</td><td>ARMOLIPID</td><td>un/una alla sera</td></tr><tr><td>0</td><td>MAALOX</td><td>MAALOX 400mg</td><td>ogni 8 ore</td></tr><tr><td>1</td><td>RATACAND</td><td>RATACAND 16 mg</td><td>1/2 al mattino</td></tr><tr><td>1</td><td>LOPRESOR</td><td>LOPRESOR</td><td>1/2 al mattino e alla sera</td></tr><tr><td>1</td><td>LIMPIDEX</td><td>LIMPIDEX 15 mg</td><td>ore 07.00 ore 22.00</td></tr><tr><td>1</td><td>MAALOX PLUS</td><td>MAALOX PLUS</td><td>ore 10.00 e ore 17.00</td></tr><tr><td>7</td><td>LOPRESOR</td><td>lopresor</td><td>un/una al mattino</td></tr><tr><td>8</td><td>LOPRESOR</td><td>LOPRESOR</td><td>null</td></tr><tr><td>8</td><td>SIVASTIN</td><td>SIVASTIN</td><td>null</td></tr><tr><td>9</td><td>VASORETIC</td><td>VASORETIC</td><td>1/2 al mattino</td></tr><tr><td>9</td><td>SIVASTIN</td><td>SIVASTIN  20</td><td>1/2 alla sera</td></tr><tr><td>9</td><td>OMEPRAZEM</td><td>OMEPRAZEM</td><td>un/una al mattino</td></tr><tr><td>10</td><td>ENAPREN</td><td>ENAPREN 20 mg</td><td>1/2 al mattino</td></tr><tr><td>10</td><td>SIVASTIN</td><td>SIVASTIN  20</td><td>1/2 alla sera</td></tr><tr><td>10</td><td>LANSOX</td><td>LANSOX 15 mg</td><td>un/una al mattino</td></tr><tr><td>10</td><td>LANOXIN</td><td>LANOXIN .125 mg</td><td>1 dopo il pasto</td></tr><tr><td>11</td><td>ANTRA</td><td>Antra compresse</td><td>1 compressa la sera</td></tr><tr><td>11</td><td>LORTAAN</td><td>Lortaan 50 mg compresse</td><td>1 compressa al mattino</td></tr><tr><td>11</td><td>LOPRESOR</td><td>Lopresor compresse</td><td>1/4 di compressa al mattino</td></tr><tr><td>12</td><td>LOPRESOR</td><td>Lopresor compresse</td><td>1/4 cp al mattino</td></tr><tr><td>13</td><td>LOPRESOR</td><td>Lopresor compresse</td><td>1/4 cp al mattino</td></tr><tr><td>14</td><td>LOPRESOR</td><td>Lopresor compresse</td><td>1/4 cp al mattino e sera</td></tr><tr><td>14</td><td>SIVASTIN</td><td>Sivastin 10</td><td>un/una alla sera</td></tr><tr><td>15</td><td>RATACAND</td><td>RATACAND 16 mg</td><td>1/2 al mattino</td></tr><tr><td>15</td><td>LOPRESOR</td><td>LOPRESOR</td><td>1/2 al mattino e alla sera</td></tr><tr><td>15</td><td>ARMOLIPID</td><td>ARMOLIPID</td><td>un/una alla sera</td></tr><tr><td>15</td><td>MAALOX PLUS</td><td>MAALOX PLUS</td><td>ogni 8 ore</td></tr><tr><td>16</td><td>RATACAND</td><td>RATACAND 16 mg</td><td>1/2 al mattino</td></tr><tr><td>16</td><td>LOPRESOR</td><td>LOPRESOR</td><td>1/2 al mattino e alla sera</td></tr><tr><td>16</td><td>ARMOLIPID</td><td>ARMOLIPID</td><td>un/una alla sera</td></tr><tr><td>16</td><td>MAALOX PLUS</td><td>MAALOX PLUS</td><td>ogni 8 ore</td></tr><tr><td>16</td><td>SINEMET</td><td>SINEMET</td><td>1/2 al mattino</td></tr><tr><td>17</td><td>RATACAND</td><td>RATACAND 16 mg</td><td>un/una al mattino</td></tr><tr><td>17</td><td>LOPRESOR</td><td>LOPRESOR</td><td>1/2 al mattino e alla sera</td></tr><tr><td>17</td><td>ARMOLIPID</td><td>ARMOLIPID</td><td>un/una alla sera</td></tr><tr><td>17</td><td>MAALOX</td><td>MAALOX 400</td><td>un/una alla sera</td></tr><tr><td>18</td><td>LOPRESOR</td><td>Lopresor compresse</td><td>1/4 cp al mattino e sera</td></tr><tr><td>18</td><td>SIVASTIN</td><td>Sivastin 10</td><td>un/una alla sera</td></tr><tr><td>19</td><td>RATACAND</td><td>RATACAND 16 mg</td><td>1/2 al mattino</td></tr><tr><td>19</td><td>LOPRESOR</td><td>LOPRESOR</td><td>1/2 al mattino e alla sera</td></tr><tr><td>19</td><td>ARMOLIPID</td><td>ARMOLIPID</td><td>un/una alla sera</td></tr><tr><td>20</td><td>RATACAND</td><td>RATACAND 16 mg</td><td>1/2 al mattino</td></tr><tr><td>20</td><td>LOPRESOR</td><td>LOPRESOR</td><td>1/2 al mattino e alla sera</td></tr><tr><td>20</td><td>ARMOLIPID</t ...

# %%
temp = df_farmaci.join(mapping.withColumnRenamed("farmaci_misspelled", "FARMACO"), on="FARMACO", how="left_outer")
finale = temp.withColumn("FARMACO", when(temp.farmaci_corretti.isNull(), temp["FARMACO"]).otherwise(temp["farmaci_corretti"])).withColumnRenamed("FARMACO", "FARMACO_FINALE")

df_farmaci = finale.drop("max(result)", "farmaci_corretti").drop_duplicates()

# %%
print("Numero di farmaci misspelled corretti:", temp.where(~temp.farmaci_corretti.isNull()).count())
print("Numero di farmaci misspelled distinct corretti:", temp.where(~temp.farmaci_corretti.isNull()).select("Farmaco").distinct().count())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Numero di farmaci misspelled corretti: 12731
# Numero di farmaci misspelled distinct corretti: 580
# </div>

# %%
display(df_farmaci)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>FARMACO_FINALE</th><th>ID_VISITA</th><th>CONFEZIONE</th><th>DOSE</th></tr></thead><tbody><tr><td>SIRDALUD</td><td>34</td><td>SIRDALUD</td><td>un/una al mattino e sera</td></tr><tr><td>NORVASC</td><td>143</td><td>NORVASC 5</td><td>1 cp al pomeriggio</td></tr><tr><td>ENAPREN</td><td>207</td><td>ENAPREN 20</td><td>un/una al mattino</td></tr><tr><td>TOTALIP</td><td>242</td><td>TOTALIP 20</td><td>un/una alla sera</td></tr><tr><td>ANSIMAR SCIROPPO</td><td>81</td><td>Ansimar sciroppo</td><td>un misurino la sera</td></tr><tr><td>PLAVIX</td><td>238</td><td>PLAVIX 75</td><td>1 dopo il pasto</td></tr><tr><td>PRITORPLUS</td><td>268</td><td>PRITOR 80/12.5 PLUS</td><td>un/una al mattino</td></tr><tr><td>METFORAL</td><td>287</td><td>Metforal 1000</td><td>1/2 cp  a pranzo e cena</td></tr><tr><td>ISOPTIN</td><td>295</td><td>Isoptin 180</td><td>Ogni 12 ore</td></tr><tr><td>METFORAL</td><td>298</td><td>Metforal 1000</td><td>1/2 cp  a pranzo e cena</td></tr><tr><td>ARMOLIPID</td><td>20</td><td>ARMOLIPID</td><td>un/una alla sera</td></tr><tr><td>NEXIUM E LIRICA</td><td>34</td><td>NEXIUM  e LIRICA</td><td>un/una alla sera</td></tr><tr><td>TORVAST</td><td>68</td><td>TORVAST 20</td><td>alla sera</td></tr><tr><td>TORVAST</td><td>70</td><td>TORVAST 20</td><td>alla sera</td></tr><tr><td>TICLOPIDINA DOC</td><td>82</td><td>Ticlopidina doc 250</td><td>1 dopo il pasto</td></tr><tr><td>ADALAT CRONO</td><td>150</td><td>ADALAT CRONO 60</td><td>1 cp al mattino</td></tr><tr><td>AMIODAR</td><td>245</td><td>AMIODAR</td><td>1 dopo il pasto</td></tr><tr><td>GLIBOMET</td><td>288</td><td>Glibomet</td><td>1 cp x 3 /die</td></tr><tr><td>FULCROSUPRA</td><td>292</td><td>Fulcrosupra</td><td>un/una alla sera</td></tr><tr><td>NORVASC</td><td>296</td><td>NORVASC 10</td><td>un/una al mattino</td></tr><tr><td>RATACAND</td><td>22</td><td>RATACAND 16 mg</td><td>1/2 al mattino</td></tr><tr><td>MANTADAN</td><td>34</td><td>MANTADAN 100</td><td>1 dopo il pasto</td></tr><tr><td>ANSIMAR SCIROPPO</td><td>83</td><td>Ansimar sciroppo</td><td>un misurino la sera</td></tr><tr><td>VENITRIN T</td><td>84</td><td>Venitrin T5</td><td>Cerotto per 12 ore</td></tr><tr><td>ZESTRIL</td><td>148</td><td>ZESTRIL 20</td><td>1 cp</td></tr><tr><td>DAONIL</td><td>188</td><td>DAONIL</td><td>mezza</td></tr><tr><td>MONOPINA</td><td>215</td><td>MONOPINA 10</td><td>1/2 cp al mattino</td></tr><tr><td>CRESTOR</td><td>269</td><td>CRESTOR 5</td><td>un/una alla sera</td></tr><tr><td>FULCROSUPRA</td><td>287</td><td>Fulcrosupra</td><td>un/una alla sera</td></tr><tr><td>LCZ</td><td>289</td><td>LCZ696</td><td>un/una al mattino</td></tr><tr><td>CARDIOASPIRIN</td><td>291</td><td>Cardioaspirin</td><td>1 dopo il pasto</td></tr><tr><td>TORVAST</td><td>95</td><td>Torvast 20</td><td>un/una alla sera</td></tr><tr><td>GLICOREST</td><td>298</td><td>Glicorest 5/500</td><td>1 cp x 3/die prima dei pasti</td></tr><tr><td>NESSUNA</td><td>43</td><td>NESSUNA</td><td>null</td></tr><tr><td>ZESTRIL</td><td>88</td><td>Zestril 20</td><td>un/una al mattino</td></tr><tr><td>ENAPREN</td><td>113</td><td>ENAPREN 20</td><td>un/una al mattino</td></tr><tr><td>BIVIS</td><td>54</td><td>BIVIS 40/5</td><td>un/una al mattino</td></tr><tr><td>VASORETIC</td><td>81</td><td>Vasoretic</td><td>un/una al mattino</td></tr><tr><td>TRIATEC</td><td>110</td><td>TRIATEC 5</td><td>un/una al mattino</td></tr><tr><td>AMIODAR</td><td>124</td><td>Amiodar cp</td><td>1 cp x 2/die per 7 giorni poi 1 cp/die</td></tr><tr><td>ACEDIUR</td><td>156</td><td>ACEDIUR</td><td>1cp</td></tr><tr><td>TENORMIN</td><td>264</td><td>TENORMIN</td><td>un/una al mattino</td></tr><tr><td>ATENOL</td><td>278</td><td>Atenol</td><td>un/una al mattino</td></tr><tr><td>METFORAL</td><td>292</td><td>Metforal 1000</td><td>1/2 cp  a pranzo e cena</td></tr><tr><td>SIVASTIN</td><td>40</td><td>SIVASTIN  20</td><td>1/2 alla sera</td></tr><tr><td>SOTALEX</td><td>93</td><td>Sotalex 80</td><td>1/ ...

# %%
#%fs rm -r dbfs:/FileStore/preprocessing/DF_FARMACI_COMPLETO

# %%
df_farmaci.coalesce(1).write.format("com.databricks.spark.csv").option("header", "true").save("dbfs:/FileStore/preprocessing/DF_FARMACI_COMPLETO")
